# %%
from langchain_ollama import ChatOllama, OllamaLLM

from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

from langchain_core.output_parsers import StrOutputParser

from langchain_core.messages import SystemMessage, HumanMessage

# %%
llm = OllamaLLM(model="llama3.2", temperature=0.7)

response = llm.invoke("What is Python?")

print(f"\nBasic Response:\n{response}\n")
# Out:
# Basic Response:
# Python is a high-level, interpreted programming language that is widely used for various purposes such as web development, scientific computing, data analysis, artificial intelligence, and more. It was created in the late 1980s by Guido van Rossum and was first released in 1991.
#
# Python is known for its simplicity, readability, and ease of use, making it a popular choice among beginners and experienced programmers alike. Here are some key features that make Python a great language:
#
# 1. **Easy to learn**: Python has a simple syntax and is relatively easy to read and write, even for those without prior programming experience.
# 2. **High-level language**: Python abstracts away many low-level details, allowing you to focus on the logic of your program without worrying about memory management or other technicalities.
# 3. **Interpreted language**: Python code can be executed directly by the interpreter, eliminating the need to compile it beforehand.
# 4. **Dynamic typing**: Python is dynamically typed, which means that you don't need to declare variable types before using them.
# 5. **Large standard library**: Python has a vast and comprehensive standard library that provides a wide range of built-in functions, modules, and classes for various tasks.
#
# Some popular uses of Python include:
#
# 1. **Web development**: Django and Flask are two popular frameworks for building web applications with Python.
# 2. **Data analysis and science**: NumPy, pandas, and scikit-learn are popular libraries for data analysis, machine learning, and scientific computing.
# 3. **Artificial intelligence and machine learning**: TensorFlow and Keras are popular frameworks for building AI and ML models with Python.
# 4. **Automation and scripting**: Python is often used for automating tasks, such as data processing, file management, and system administration.
# 5. **Education**: Python is a popular teaching language due to its simplicity, readability, and ease of use.
#
# Overall, Python is a versatile and widely-used language that has become an essential tool in many industries and fields.

# %% [markdown]
# # Prompt Templates

# %%
# Create a prompt template

template = """You are a helpful assistant. Answer the following question:

Question: {question}

Answer:"""

prompt = PromptTemplate(
    input_variables=["question"],
    template=template
)

# Format the prompt
formatted_prompt = prompt.format(question="What is machine learning?")

print(f"\nFormatted Prompt:\n{formatted_prompt}\n")

# Use with LLM
response = llm.invoke(formatted_prompt)
print(f"Response:\n{response}\n")
# Out:
# Formatted Prompt:
# You are a helpful assistant. Answer the following question:
#
# Question: What is machine learning?
#
# Answer:
#
# Response:
# Machine learning is a type of artificial intelligence (AI) that enables systems to automatically learn and improve from experience without being explicitly programmed.
#
# In traditional programming, a computer is given a set of rules and instructions to follow in order to complete a task. However, with machine learning, the system learns by analyzing data, identifying patterns, and making predictions or decisions based on that data.
#
# Machine learning involves several key techniques, including:
#
# 1. Supervised learning: The system is trained on labeled data, where the correct output is already known.
# 2. Unsupervised learning: The system is trained on unlabeled data, and it must find patterns or relationships in the data.
# 3. Reinforcement learning: The system learns by interacting with an environment and receiving feedback in the form of rewards or penalties.
#
# Machine learning has many applications in areas such as:
#
# 1. Image recognition
# 2. Natural language processing
# 3. Predictive analytics
# 4. Recommendation systems
#
# The benefits of machine learning include:
#
# 1. Improved accuracy and efficiency
# 2. Increased scalability and flexibility
# 3. Ability to handle complex and dynamic data
#
# However, machine learning also has its limitations and challenges, such as:
#
# 1. Data quality and availability
# 2. Model interpretability and explainability
# 3. Bias and fairness concerns
#
# Overall, machine learning is a powerful tool that can help organizations automate tasks, gain insights from data, and make more informed decisions.

# %% [markdown]
# # Chain - Prompt + LLM + Parser

# %%
# Create a simple chain using LCEL (LangChain Expression Language)

chain = prompt | llm | StrOutputParser()

# Invoke the chain
result = chain.invoke({"question": "What is deep learning?"})

print(f"\nChain Result:\n{result}\n")
# Out:
# Chain Result:
# Deep learning is a subset of machine learning that uses artificial neural networks (ANNs) to analyze and interpret data. It's called "deep" because these neural networks have multiple layers, similar to the structure of the human brain.
#
# In traditional machine learning methods, models are typically simple and use a single layer or a few layers to make predictions. In contrast, deep learning models can have hundreds or even thousands of layers, allowing them to learn complex patterns in data that would be difficult for simpler models to detect.
#
# Deep learning is particularly effective when dealing with:
#
# 1. Image recognition: Deep neural networks can recognize objects, faces, and scenes in images.
# 2. Natural Language Processing (NLP): Deep learning models can understand and generate human language, such as text and speech.
# 3. Speech recognition: Deep learning algorithms can transcribe spoken words into written text.
#
# The key characteristics of deep learning include:
#
# 1. **Large datasets**: Deep learning requires massive amounts of data to train the models.
# 2. **Complex neural networks**: Multiple layers with non-linear transformations enable the models to learn complex patterns in data.
# 3. **Automatic optimization**: Algorithms can automatically adjust the model's parameters to optimize performance.
#
# Some popular deep learning techniques include:
#
# 1. Convolutional Neural Networks (CNNs)
# 2. Recurrent Neural Networks (RNNs)
# 3. Generative Adversarial Networks (GANs)
#
# Overall, deep learning has revolutionized many fields, including computer vision, NLP, and robotics, by enabling machines to learn from data in a more intelligent and effective way.

# %% [markdown]
# # Chat Prompt Templates

# %%
# Initialize Chat Model
chat_model = ChatOllama(model="llama3.2", temperature=0.7)

# Create chat prompt template
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert {role}. Always provide detailed and accurate information."),
    ("human", "{user_input}")
])

# Format and invoke
messages = chat_prompt.format_messages(
    role="Python developer",
    user_input="How do I handle exceptions in Python?"
)

response = chat_model.invoke(messages)
print(f"\nChat Response:\n{response.content}\n")
# Out:
# Chat Response:
# **Handling Exceptions in Python**
# =====================================
#
# Exceptions are errors that occur during the execution of a program. In Python, exceptions can be handled using try-except blocks.
#
# **Basic Syntax**
# ---------------
#
# The basic syntax for handling exceptions is:
# ```python
# try:
#     # code that may raise an exception
# except ExceptionType:
#     # code to handle the exception
# ```
# **Types of Exceptions**
# -----------------------
#
# Python has several built-in exception types, including:
#
# *   `Exception`: The base class for all exceptions.
# *   `SyntaxError`: Raised when there's a syntax error in the code.
# *   `TypeError`: Raised when a value is of an incorrect type.
# *   `ValueError`: Raised when a function receives an argument with the correct type but an incorrect value.
#
# **Example Use Case**
# --------------------
#
# Here's an example that demonstrates how to handle exceptions using try-except blocks:
# ```python
# def divide_numbers(a, b):
#     try:
#         result = a / b
#         return result
#     except ZeroDivisionError:
#         print("Error: Division by zero is not allowed.")
#     except TypeError:
#         print("Error: Both inputs must be numbers.")
#
# # Test the function with valid input
# print(divide_numbers(10, 2))  # Output: 5.0
#
# # Test the function with invalid input
# print(divide_numbers(10, 0))  # Output: Error: Division by zero is not allowed.
# print(divide_numbers("a", 2))  # Output: Error: Both inputs must be numbers.
# ```
# **Raising Custom Exceptions**
# -----------------------------
#
# You can also raise custom exceptions using the `raise` keyword:
# ```python
# class InsufficientBalanceError(Exception):
#     pass
#
# def withdraw_balance(balance, amount):
#     if balance < amount:
#         raise InsufficientBalanceError("Insufficient balance.")
#     return balance - amount
#
# try:
#     print(withdraw_balance(1000, 1500))  # Raises an exception
# except InsufficientBalanceError as e:
#     print(e)  # Output: Insufficient balance.
# ```
# **Best Practices**
# ------------------
#
# Here are some best practices for handling exceptions in Python:
#
# *   Always handle the most specific exception type first.
# *   Keep your exception handling code concise and focused on error recovery.
# *   Log or report errors to help diagnose issues.
#
# By following these guidelines, you can write robust and error-free Python code.

# %% [markdown]
# # Multi-Variable Templates

# %%
# Template with multiple variables

multi_template = """You are a {profession} with {years} years of experience.

Task: {task}

Context: {context}

Provide a professional response:"""

multi_prompt = PromptTemplate(
    input_variables=["profession", "years", "task", "context"],
    template=multi_template
)

# Create chain
multi_chain = multi_prompt | llm | StrOutputParser()

# Invoke with multiple inputs
result = multi_chain.invoke({
    "profession": "data scientist",
    "years": "10",
    "task": "Explain gradient descent",
    "context": "Teaching to beginners"
})

print(f"\nMulti-variable Response:\n{result}\n")
# Out:
# Multi-variable Response:
# Gradient Descent: A Fundamental Algorithm in Machine Learning
#
# As a data scientist, I'm excited to introduce you to one of the most fundamental algorithms in machine learning: Gradient Descent. This algorithm is widely used for optimizing models and achieving optimal results in various applications.
#
# What is Gradient Descent?
# ------------------------
#
# Gradient Descent is an optimization algorithm that minimizes the loss function of a model by iteratively adjusting the parameters in the direction of the negative gradient of the loss function. The goal is to find the optimal values of the parameters that result in the minimum value of the loss function.
#
# How Does Gradient Descent Work?
# --------------------------------
#
# The process of Gradient Descent can be broken down into several steps:
#
# 1. **Initialization**: We start by initializing the model's parameters, typically with random or default values.
# 2. **Loss Calculation**: We calculate the loss function for the current model parameters using a dataset.
# 3. **Gradient Computation**: We compute the gradient of the loss function with respect to each parameter. The gradient represents the direction in which the loss decreases.
# 4. **Parameter Update**: We update the model parameters by moving in the opposite direction of the negative gradient, effectively reducing the loss.
# 5. **Iteration**: Steps 2-4 are repeated until convergence or a stopping criterion is met.
#
# Key Concepts:
#
# *   **Learning Rate** (α): The learning rate determines how quickly we move towards the optimal solution. A high learning rate can lead to faster convergence but also increases the risk of overshooting.
# *   **Optimization Method**: Gradient Descent can be used in conjunction with various optimization methods, such as Stochastic Gradient Descent (SGD) or Mini-Batch Gradient Descent, which reduce the computational cost and improve stability.
#
# Types of Gradient Descent:
# -----------------------------
#
# There are several variants of Gradient Descent, each suited for specific applications:
#
# *   **Batch Gradient Descent**: This is the original version of Gradient Descent, where we use the entire dataset to compute the gradient.
# *   **Stochastic Gradient Descent (SGD)**: This variant uses a single data point to compute the gradient at each iteration.
# *   **Mini-Batch Gradient Descent**: This combines the benefits of both batch and stochastic gradients by using a small subset of the dataset.
#
# Advantages and Challenges:
# ---------------------------
#
# Gradient Descent has several advantages, including:
#
# *   **Simple Implementation**: The algorithm is easy to understand and implement.
# *   **Wide Applicability**: Gradient Descent can be used for various machine learning tasks, such as linear regression, logistic regression, and neural networks.
#
# However, Gradient Descent also faces some challenges, including:
#
# *   **Convergence Issues**: If the initial parameters are not close enough to the optimal solution or if the learning rate is too high, the algorithm may converge slowly or get stuck in a local minimum.
# *   **Overfitting**: If the model is overly complex and the learning rate is too low, the algorithm can lead to overfitting.
#
# Conclusion:
# ----------
#
# In conclusion, Gradient Descent is an essential algorithm for machine learning that enables us to optimize models and achieve optimal results. By understanding the key concepts, advantages, and challenges of Gradient Descent, you'll be better equipped to tackle various machine learning tasks and improve your skills as a data scientist.

# %% [markdown]
# # Prompts

# %% [markdown]
#    - Be specific and clear
#
#    - Provide context and examples
#
#    - Use delimiters (###, ---, ===) for clarity
#
#    - Specify output format explicitly
#
#    - Use role-playing for better responses

# %% [markdown]
# # Few-Shot Prompting

# %%
few_shot_template = """You are a sentiment analyzer. Classify the sentiment as Positive, Negative, or Neutral.

Examples:
Text: "I love this product!"
Sentiment: Positive

Text: "This is the worst experience ever."
Sentiment: Negative

Text: "The package arrived on time."
Sentiment: Neutral

Now classify:
Text: "{text}"
Sentiment:"""

few_shot_prompt = PromptTemplate(
    input_variables=["text"],
    template=few_shot_template
)

chain = few_shot_prompt | llm | StrOutputParser()

# Test few-shot learning
test_texts = [
    "This movie was amazing!",
    "I'm disappointed with the service.",
    "The product works as described."
]

for text in test_texts:
    sentiment = chain.invoke({"text": text})
    print(f"Text: {text}")
    print(f"Sentiment: {sentiment.strip()}\n")

# %% [markdown]
# # Conversational Chain

# %%
conversation_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a friendly AI assistant. Keep responses concise."),
    ("human", "{input}")
])

conversation_chain = conversation_prompt | chat_model | StrOutputParser()

# Simulate conversation
conversation = [
    "Hi, what's your name?",
    "Can you help me learn Python?",
    "What should I learn first?"
]

for message in conversation:
    print(f"User: {message}")
    response = conversation_chain.invoke({"input": message})
    print(f"AI: {response}\n")

# %% [markdown]
# # Role-Based Prompting

# %%
role_prompt = ChatPromptTemplate.from_messages([
    ("system", """You are acting as a {role}. 
    
Your characteristics:
- {trait1}
- {trait2}
- {trait3}

Respond in character to the following:"""),
    ("human", "{query}")
])

role_chain = role_prompt | chat_model | StrOutputParser()

# Example: Tech support role
response = role_chain.invoke({
    "role": "senior technical support engineer",
    "trait1": "Patient and understanding",
    "trait2": "Explains technical concepts simply",
    "trait3": "Always provides step-by-step solutions",
    "query": "My computer won't start. What should I do?"
})

print(f"Response:\n{response}\n")

# %% [markdown]
# # Output Formatting

# %%
structured_template = """Analyze the following text and provide a structured response.

Text: {text}

Provide your analysis in this exact format:
Topic: [main topic]
Sentiment: [positive/negative/neutral]
Key Points: [list 3 key points]
Summary: [one sentence summary]"""

structured_prompt = PromptTemplate(
    input_variables=["text"],
    template=structured_template
)

structured_chain = structured_prompt | llm | StrOutputParser()

analysis_text = "LangChain is an amazing framework for building LLM applications. It makes it easy to chain together prompts, models, and parsers. Developers love its flexibility and extensive documentation."

result = structured_chain.invoke({"text": analysis_text})
print(f"Structured Analysis:\n{result}\n")

# %% [markdown]
# # What's the difference between OllamaLLM and ChatOllama?

# %%
Use ChatOllama for 95% of tasks because:

    More powerful and flexible
    Better handles context and roles
    Easier to build conversations
    Works better with prompt templates

Use OllamaLLM only for:

    Very simple, single-shot completions
    When you don't need conversation structure

# %% [markdown]
# ### When would you use temperature=0.0 vs temperature=0.9?

# %% [markdown]
# Temperature controls randomness and creativity in the model's responses.

# %% [markdown]
# ❄️ Temperature = 0.0 (Cold/Deterministic)
#
# When to use:
#
#     ✅ Factual questions
#     ✅ Code generation
#     ✅ Math problems
#     ✅ Data extraction
#     ✅ Translation
#     ✅ Classification tasks
#     ✅ When you need consistent, repeatable answers

# %% [markdown]
# Characteristics:
#
#     Always picks the most likely next word
#     Same input → Same output (mostly)
#     Focused, precise, conservative
#     No creativity or variation

# %% [markdown]
# 🔥 Temperature = 0.9-1.0 (Hot/Creative)
#
# When to use:
#
#     ✅ Creative writing (stories, poems)
#     ✅ Brainstorming ideas
#     ✅ Marketing copy variations
#     ✅ Casual conversation
#     ✅ Generating multiple alternatives
#     ✅ When you want diverse, unexpected responses

# %% [markdown]
# Characteristics:
#
#     Considers less likely word choices
#     Same input → Different outputs each time
#     More creative, diverse, surprising
#     Can be less accurate/factual

# %% [markdown]
# 🌤️ Temperature = 0.4-0.7 (Balanced) ⭐ Most Common
#
# When to use:
#
#     ✅ General conversation
#     ✅ Explanations
#     ✅ Product descriptions
#     ✅ Email writing
#     ✅ Most everyday tasks

# %% [markdown]
# Characteristics:
#
#     Good balance of accuracy and variety
#     Reliable but not boring
#     Default choice for most applications
