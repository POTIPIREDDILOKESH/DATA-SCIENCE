# %% [markdown]
# ### 1 What is LangChain?
#
# LangChain is a Python library that helps to build applications using Large Language Models (LLMs) like GPT, LLaMA, Mistral, Gemini, etc.
#
# LangChain as glue that connects:
#
#         * an LLM
#
#         * data (PDFs, text files, databases)
#
#         * tools (search, calculators, APIs)
#
#         * logic (memory, steps, workflows)
#
# so that we can build smart AI apps, not just one-time prompts.

# %%
pip show langchain
# Out:
# Name: langchainNote: you may need to restart the kernel to use updated packages.
#
# Version: 1.2.8
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\nvgra\anaconda3\annacond\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by: embedchain

# %% [markdown]
# ---

# %% [markdown]
# ### 2 Why do we need LangChain?
#
# If we use an LLM without LangChain, we usually:
#
#     * send a prompt
#
#     * get a response
#
#     * stop
#
# If we use an LLM with LangChain, we can:
#
#     * load documents 📄
#
#     * split them into chunks
#
#     * create embeddings
#
#     * store them in FAISS / Chroma
#
#     * retrieve relevant context (RAG)
#
#     * maintain memory
#
#     * call tools
#
#     * build multi-step workflows

# %% [markdown]
# ---

# %% [markdown]
# ### Without LangChain:
#
#                     Prompt → LLM → Answer

# %% [markdown]
# ### With LangChain:
#
#                     Question
#                        ↓
#                     Retrieve relevant documents
#                        ↓
#                     Add context to prompt
#                        ↓
#                     LLM generates answer

# %% [markdown]
# Definition:
#
# LangChain is a framework that simplifies building LLM-powered applications by <b> connecting models with  data, memory, tools, and workflows</b>.

# %% [markdown]
# ---

# %% [markdown]
# 3. What is langchain_ollama?
#
# langchain_ollama is a LangChain integration package that allows, to use Ollama LLMs (like LLaMA, Mistral, Gemma, Phi-3, etc.) inside LangChain.
#
#     ✅ It connects LangChain → Ollama
#
#     ✅ So LangChain can send prompts to local models
#
#     ✅ No API key required
#
#     ✅ Works offline

# %% [markdown]
# 4. Why do we need ChatOllama?
#
# ChatOllama is the LangChain "chat model" wrapper for Ollama.
#
#     It sends your message to a local Ollama model and returns the LLM’s response.
#
#     Think of it like:
#
#         ✅ "LLM interface for Ollama models"
#
#         ✅ "ChatGPT-like model but running locally"

# %% [markdown]
# ### Important: .invoke() vs .predict()

# %% [markdown]
#     ✅ .invoke() → returns AIMessage (with content + metadata)

# %% [markdown]
#     ✅ .predict() → returns ONLY TEXT (simple)

# %%
# ! pip install langchain langchain-ollama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2")

response = llm.invoke("Hello! Explain AI in simple words.")

print(response.content)
# Out:
# AI, or Artificial Intelligence, refers to computer systems that can think and learn like humans.
#
# Imagine you have a robot friend who can:
#
# 1. Understand and respond to questions (like I'm doing now!)
# 2. Learn from experiences and improve over time
# 3. Make decisions based on patterns and data
#
# These are just a few examples of how AI works. There are many types of AI, including:
#
# * Machine learning: helping computers learn from data and make predictions
# * Natural Language Processing (NLP): allowing computers to understand and generate human-like language
# * Computer vision: enabling computers to see, recognize, and interpret visual data
#
# In simple terms, AI is like a super-smart computer that can help us solve problems, automate tasks, and create new possibilities.
#
# Do you have any specific questions about AI or would you like me to explain something in more detail?

# %%
llm = ChatOllama(model="mistral")

response = llm.invoke("Hello! Explain AI in simple words.")

print(response.content)
# Out:
#  Hello! In simple terms, AI (Artificial Intelligence) refers to the ability of a computer program or machine to perform tasks that usually require human intelligence, such as learning, problem-solving, and decision-making. It involves creating algorithms that allow computers to understand, interpret, and respond to data in a way that mimics human thought processes. The goal is to create machines that can think, learn, and adapt like humans, but at a much faster pace and with unlimited computational power.

# %% [markdown]
# Why use ChatOllama in LangChain?
#
#  Because it lets you use local LLMs inside:
#
#     ✅ RAG
#
#     ✅ Agents
#
#     ✅ Tools
#
#     ✅ Chains
#
#     ✅ LangGraph
#
#     ✅ Memory/chat systems

# %% [markdown]
# ✅ Which is faster: LLaMA 3.2 or Mistral?
#
# 🏆 Overall Faster in Response Time → MISTRAL
#
#     Mistral models (like mistral, mistral:instruct, mistral-nemo, etc.) usually respond faster than LLaMA 3.2 on most laptops.

# %% [markdown]
# ### Comparision

# %% [markdown]
# ✅ Fastest overall: Mistral models
#
# ✅ Best for accuracy: LLaMA 3.1 / 3.2 (bigger models)
#
# ✅ Best for speed: Mistral or LLaMA 3.2 (1B / 3B)
